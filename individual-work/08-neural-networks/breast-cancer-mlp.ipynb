# %% [markdown]
# 9.2) Problem Solving in Python
# Your task this week is to create a new notebook called
# "[yourstudentID]_Week_9_Problem Solving Tasks.ipynb". In this file you need to create
# cells to create your own neural network. Go to the SciKit-Learn datasets page and select
# a dataset to train and classify. Do not use the Digits dataset that was used in the sample
# workbook. Include a link to your chosen dataset in your workbook. You are required to
# train and test your neural network 7 times, keeping the results of each model in your
# workbook. Use the following settings for your models:
# 1. Create a MLP with the same settings as the sample workbook. (Everything
# default, 3 hidden layers with 30 neurons each). Train and Test
# 2. Increase your learning rate (alpha) to 0.1. Retrain and retest.
# 3. Change your learning rate back to default. Decrease your momentum to 0.1.
# Retrain and retest.
# 4. Keep momentum the same. Increase max_iter to 1000. Retrain and retest.
# 5. Now try to build a model with the highest level of accuracy you can. You can
# change any of the parameters including max_iter, alpha, momentum, and
# hidden layers. Take your time testing different configurations until you find
# one you like.
# 6. Given the following structure and the inputs and weights provided, calculate the
# output of the network for 𝑦𝑦1 and 𝑦𝑦2.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()
data_shape = dataset['data'].shape
print("Data Loaded: {2}\nTarget Loaded: {3}\nSamples: {0}\nFeatures: {1}\n"
      .format(data_shape[0], data_shape[1], "data" in dataset.keys(), "target" in dataset.keys()))


#df = load_breast_cancer()
# Out:
# Data Loaded: True
# Target Loaded: True
# Samples: 569
# Features: 30

# %%
X = dataset.data
y = dataset.target

X_train, X_test, y_train , y_test = train_test_split(X,y)

# %%
# StandardScaler().fit(x_train)

scaler = StandardScaler()

# Fit only to the training data

scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 9.2)     1) Create a MLP with the same settings as the sample workbook. (Everything 
# default, 3 hidden layers with 30 neurons each). Train and Test
# default parameteres


mlp = MLPClassifier(hidden_layer_sizes=(30,30,30))
mlp.fit(X_train,y_train)

training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.9790209790209791

# %%
predictions = mlp.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[51  8]
#  [ 2 82]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        59
#            1       0.91      0.98      0.94        84
#
#     accuracy                           0.93       143
#    macro avg       0.94      0.92      0.93       143
# weighted avg       0.93      0.93      0.93       143

# %%
# 9.2)     2) Increase your learning rate (alpha) to 0.1. Retrain and retest.

# default parameteres (Alpha 0.1 retrain and retest)



training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.972027972027972
# C:\Users\Georg\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# 9.2)     3) Change your learning rate back to default. Decrease your momentum to 0.1. Retrain and retest.

# default parameteres (decrease momentum)

mlp = MLPClassifier(hidden_layer_sizes=(30,30,30), momentum = 0.1)
mlp.fit(X_train,y_train)

training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.951048951048951

# %%
# 9.2)     4) 4. Keep momentum the same. Increase max_iter to 1000. Retrain and retest.


mlp = MLPClassifier(hidden_layer_sizes=(30,30,30), momentum = 0.1, max_iter = 1000)
mlp.fit(X_train,y_train)

training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.972027972027972

# %%
# 9.2)     5) 5. Keep momentum the same. Increase max_iter to 1000. Retrain and retest.
# Now try to build a model with the highest level of accuracy you can. 
# You can change any of the parameters including max_iter, alpha, momentum, and hidden layers. 
# Take your time testing different configurations until you find one you like.


mlp = MLPClassifier(hidden_layer_sizes=(30,30,30),alpha = 0.07, momentum = 0.07, max_iter = 1200)
mlp.fit(X_train,y_train)

training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.972027972027972

# %%
# 9.2)     5) 6. Keep momentum the same. Increase max_iter to 1000. Retrain and retest.
# Now try to build a model with the highest level of accuracy you can. 
# You can change any of the parameters including max_iter, alpha, momentum, and hidden layers. 
# Take your time testing different configurations until you find one you like.



mlp = MLPClassifier(hidden_layer_sizes=(30,30,30),alpha = 0.07, momentum = 0.07, max_iter = 1200)
mlp.fit(X_train,y_train)

training_score = mlp.score(X_train, y_train)
testing_score = mlp.score(X_test, y_test)

print("Training score: ", training_score)
print("Testing score: ", testing_score)
# Out:
# Training score:  1.0
# Testing score:  0.951048951048951
